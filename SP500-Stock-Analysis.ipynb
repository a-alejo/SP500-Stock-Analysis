# %%
# Load libraries and the dataset - Preview data with number of rows/columns
import yfinance as yf
import pandas as pd
import numpy as np

# %%
# Select Apple stocks as a test
apple = yf.download("AAPL", start="2000-01-01", end="2022-12-31")
apple
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03    0.936384    1.004464    0.907924    0.999442    0.848323
# 2000-01-04    0.966518    0.987723    0.903460    0.915179    0.776801
# 2000-01-05    0.926339    0.987165    0.919643    0.928571    0.788168
# 2000-01-06    0.947545    0.955357    0.848214    0.848214    0.719961
# 2000-01-07    0.861607    0.901786    0.852679    0.888393    0.754065
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.299820
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.477585
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.504539
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  129.059372
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.378006
#
#                Volume
# Date
# ...

# %% [markdown]
# ### Selecting the top 3 spy holdings

# %%
stock_pick = ["AAPL", "MSFT", "AMZN"]
stocks = yf.download(stock_pick, start="2000-01-01", end="2022-12-31")
stocks
# Out:
# [*********************100%%**********************]  3 of 3 completed
#              Adj Close                              Close             \
#                   AAPL       AMZN        MSFT        AAPL       AMZN
# Date
# 2000-01-03    0.848323   4.468750   36.205597    0.999442   4.468750
# 2000-01-04    0.776801   4.096875   34.982574    0.915179   4.096875
# 2000-01-05    0.788168   3.487500   35.351414    0.928571   3.487500
# 2000-01-06    0.719961   3.278125   34.167225    0.848214   3.278125
# 2000-01-07    0.754065   3.478125   34.613731    0.888393   3.478125
# ...                ...        ...         ...         ...        ...
# 2022-12-23  131.299820  85.250000  237.112091  131.860001  85.250000
# 2022-12-27  129.477585  83.040001  235.354095  130.029999  83.040001
# 2022-12-28  125.504539  81.820000  232.940552  126.040001  81.820000
# 2022-12-29  129.059372  84.180000  239.376633  129.610001  84.180000
# ...

# %%
stocks.head()
# Out:
#            Adj Close                          Close                      \
#                 AAPL      AMZN       MSFT      AAPL      AMZN      MSFT
# Date
# 2000-01-03  0.848323  4.468750  36.205597  0.999442  4.468750  58.28125
# 2000-01-04  0.776801  4.096875  34.982574  0.915179  4.096875  56.31250
# 2000-01-05  0.788168  3.487500  35.351414  0.928571  3.487500  56.90625
# 2000-01-06  0.719961  3.278125  34.167225  0.848214  3.278125  55.00000
# 2000-01-07  0.754065  3.478125  34.613731  0.888393  3.478125  55.71875
#
#                 High                          Low                      \
#                 AAPL      AMZN     MSFT      AAPL      AMZN      MSFT
# Date
# 2000-01-03  1.004464  4.478125  59.3125  0.907924  3.952344  56.00000
# 2000-01-04  0.987723  4.575000  58.5625  0.903460  4.087500  56.12500
# 2000-01-05  0.987165  3.756250  58.1875  0.919643  3.400000  54.68750
# 2000-01-06  0.955357  3.634375  56.9375  0.848214  3.200000  54.18750
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5787 entries, 2000-01-03 to 2022-12-30
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  5787 non-null   float64
#  1   (Adj Close, AMZN)  5787 non-null   float64
#  2   (Adj Close, MSFT)  5787 non-null   float64
#  3   (Close, AAPL)      5787 non-null   float64
#  4   (Close, AMZN)      5787 non-null   float64
#  5   (Close, MSFT)      5787 non-null   float64
#  6   (High, AAPL)       5787 non-null   float64
#  7   (High, AMZN)       5787 non-null   float64
#  8   (High, MSFT)       5787 non-null   float64
#  9   (Low, AAPL)        5787 non-null   float64
#  10  (Low, AMZN)        5787 non-null   float64
#  11  (Low, MSFT)        5787 non-null   float64
#  12  (Open, AAPL)       5787 non-null   float64
#  13  (Open, AMZN)       5787 non-null   float64
#  14  (Open, MSFT)       5787 non-null   float64
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL         AMZN         MSFT         AAPL         AMZN
# count  5787.000000  5787.000000  5787.000000  5787.000000  5787.000000
# mean     28.648579    34.303404    61.771657    29.956205    34.303404
# std      42.850517    49.417387    76.545877    43.170829    49.417387
# min       0.198861     0.298500    11.327568     0.234286     0.298500
# 25%       1.587098     2.200250    18.956084     1.869821     2.200250
# 50%      10.828218     9.294500    22.923225    12.757143     9.294500
# 75%      33.181681    44.451250    60.225088    35.453751    44.451250
# max     180.190964   186.570496   337.621094   182.009995   186.570496
#
#                            High                                    Low  \
#               MSFT         AAPL         AMZN         MSFT         AAPL
# count  5787.000000  5787.000000  5787.000000  5787.000000  5787.000000
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close', 'AMZN'),
#             ('Adj Close', 'MSFT'),
#             (    'Close', 'AAPL'),
#             (    'Close', 'AMZN'),
#             (    'Close', 'MSFT'),
#             (     'High', 'AAPL'),
#             (     'High', 'AMZN'),
#             (     'High', 'MSFT'),
#             (      'Low', 'AAPL'),
#             (      'Low', 'AMZN'),
#             (      'Low', 'MSFT'),
#             (     'Open', 'AAPL'),
#             (     'Open', 'AMZN'),
#             (     'Open', 'MSFT'),
#             (   'Volume', 'AAPL'),
#             (   'Volume', 'AMZN'),
#             (   'Volume', 'MSFT')],
#            )

# %%
# Create a copy of the 'stocks' DataFrame
stocks_flatten = stocks.copy()

# Convert multi-index into tuple incase needed
stocks_flatten.columns = stocks_flatten.columns.to_flat_index()

# preview changes
stocks_flatten.head()
# Out:
#             (Adj Close, AAPL)  (Adj Close, AMZN)  (Adj Close, MSFT)  \
# Date
# 2000-01-03           0.848323           4.468750          36.205597
# 2000-01-04           0.776801           4.096875          34.982574
# 2000-01-05           0.788168           3.487500          35.351414
# 2000-01-06           0.719961           3.278125          34.167225
# 2000-01-07           0.754065           3.478125          34.613731
#
#             (Close, AAPL)  (Close, AMZN)  (Close, MSFT)  (High, AAPL)  \
# Date
# 2000-01-03       0.999442       4.468750       58.28125      1.004464
# 2000-01-04       0.915179       4.096875       56.31250      0.987723
# 2000-01-05       0.928571       3.487500       56.90625      0.987165
# 2000-01-06       0.848214       3.278125       55.00000      0.955357
# 2000-01-07       0.888393       3.478125       55.71875      0.901786
#
#             (High, AMZN)  (High, MSFT)  (Low, AAPL)  (Low, AMZN)  (Low, MSFT)  \
# Date
# ...

# %%
close = stocks["Close"]
close
# Out:
#                   AAPL       AMZN        MSFT
# Date
# 2000-01-03    0.999442   4.468750   58.281250
# 2000-01-04    0.915179   4.096875   56.312500
# 2000-01-05    0.928571   3.487500   56.906250
# 2000-01-06    0.848214   3.278125   55.000000
# 2000-01-07    0.888393   3.478125   55.718750
# ...                ...        ...         ...
# 2022-12-23  131.860001  85.250000  238.729996
# 2022-12-27  130.029999  83.040001  236.960007
# 2022-12-28  126.040001  81.820000  234.529999
# 2022-12-29  129.610001  84.180000  241.009995
# 2022-12-30  129.929993  84.000000  239.820007
#
# [5787 rows x 3 columns]

# %%
# Load visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Set the width and height of the figure
plt.figure(figsize=(15, 5))

# Create a line plot
sns.lineplot(data=close, dashes=False)
# Out:
# <Axes: xlabel='Date'>

# %%
# Looking at the stocks from 2015

close_reset = close.copy()

close_reset = close_reset.reset_index()
close_reset = close_reset[close_reset["Date"] > "2015"]
close_reset.set_index("Date", inplace=True)


# Create a line plot
sns.lineplot(data=close_reset, dashes=False)
plt.title("Prices after 2015")
plt.ylabel("Stock Price")
# Out:
# Text(0, 0.5, 'Stock Price')

# %%
# Normalize the data by multiplying close price by 100
close_normalized = close_reset.copy()
close_normalized = close_normalized.div(close_normalized.iloc[0]).mul(100)

# Set the width and height of the figure
plt.figure(figsize=(15, 5))

# Create a line plot
sns.lineplot(data=close_normalized, dashes=False)
plt.title("Normalized Stock Price")
plt.ylabel("Stock Price")
# Out:
# Text(0, 0.5, 'Stock Price')

# %%
# Create a new dataframe containing Apple's close price
apple_close = apple["Close"].copy().to_frame()

# Get price difference between a day
apple_close["price_diff"] = apple_close["Close"].diff()

# Calculate the percentage difference between a day
apple_close["percent_diff"] = apple_close["Close"].pct_change(periods=1).mul(100)

# Preview table
apple_close
# Out:
#                  Close  price_diff  percent_diff
# Date
# 2000-01-03    0.999442         NaN           NaN
# 2000-01-04    0.915179   -0.084263     -8.431001
# 2000-01-05    0.928571    0.013392      1.463317
# 2000-01-06    0.848214   -0.080357     -8.653837
# 2000-01-07    0.888393    0.040179      4.736896
# ...                ...         ...           ...
# 2022-12-23  131.860001   -0.369995     -0.279812
# 2022-12-27  130.029999   -1.830002     -1.387837
# 2022-12-28  126.040001   -3.989998     -3.068521
# 2022-12-29  129.610001    3.570000      2.832434
# 2022-12-30  129.929993    0.319992      0.246888
#
# [5787 rows x 3 columns]

# %%
# Get the last business day of each month
apple_close.resample("bm").last()
# Out:
#                  Close  price_diff  percent_diff
# Date
# 2000-01-31    0.926339    0.018973      2.090997
# 2000-02-29    1.023438    0.012277      1.214150
# 2000-03-31    1.212612    0.089844      8.002008
# 2000-04-28    1.107701   -0.023995     -2.120273
# 2000-05-31    0.750000   -0.031808     -4.068520
# ...                ...         ...           ...
# 2022-08-31  157.220001   -1.690002     -1.063497
# 2022-09-30  138.199997   -4.279999     -3.003930
# 2022-10-31  153.339996   -2.400009     -1.541036
# 2022-11-30  148.029999    6.860001      4.859390
# 2022-12-30  129.929993    0.319992      0.246888
#
# [276 rows x 3 columns]

# %%
# Plot the trading returns range
sns.histplot(data=apple_close["percent_diff"].resample("bm").last())
plt.title("Returns Percentage Range")

# Zoom in plot to hide outliers
plt.xlim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
close.describe().T  # [['mean','std']]
# Out:
#        count       mean        std        min        25%        50%  \
# AAPL  5787.0  29.956205  43.170829   0.234286   1.869821  12.757143
# AMZN  5787.0  34.303404  49.417387   0.298500   2.200250   9.294500
# MSFT  5787.0  68.863859  75.413329  15.150000  26.950001  31.540001
#
#             75%         max
# AAPL  35.453751  182.009995
# AMZN  44.451250  186.570496
# MSFT  65.475002  343.109985

# %%
# Separate the mean and std
closed = close.describe().T[["mean", "std"]]

for index, row in closed.iterrows():
    x = row["std"]
    y = row["mean"]
    plt.scatter(x, y)
    plt.annotate(index, (x, y))


plt.xlabel("Annual Risk (STD)")
plt.ylabel("Annual Return (Mean)")
plt.title("Risk vs Reward")
# Out:
# Text(0.5, 1.0, 'Risk vs Reward')

# %% [markdown]
# As we see above on the scatter plot - Of the three stocks Apple is the "safer" option with relative low risk to return, Amazon has a much higher risk but a low return rate and on the far right side Microsoft offers a higher return to risk when comparing the three
